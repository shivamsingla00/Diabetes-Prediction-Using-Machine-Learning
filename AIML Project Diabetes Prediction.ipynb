# %% [markdown]
# # Description
#
# The objective of this diabetes dataset is to predict whether patient has diabetes or not. The datasets consists of several medical predictor (independent) variables and one target variable. Predictor variables include pregnancies,Glucose,Blood Pressure,Skin Thickness,Insulin,BMI,DiabetesPedigreeFunction,Age and Outcome target variable.
#
# **Description about the columns**
#
#     1) Pregnancies: Number of times pregnant
#
#     2) Glucose: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#
#     3) Blood Pressure: Diastolic blood pressure (mm Hg)
#
#     4) SkinThickness: Triceps skin fold thickness (mm)
#
#     5) Insulin: 2-Hour serum insulin (mu U/ml)
#
#     6) BMI: Body mass index (weight in kg/(height in m)^2)
#
#     7) DiabetesPedigreeFunction: Diabetes pedigree function
#
#     8) Age: Age (years)
#
#     9) Outcome: Class variable (0 or 1)

# %% [markdown]
# ### Step 1: Importing libraries like Numpy, Pandas Matplotlib and Seaborn
#
# **Numpy:** NumPy is a general-purpose array-processing package. It provides a high-performance multidimensional array object. It is the fundamental package for scientific computing with Python.Numerical Analysis Library
#
# **Pandas:** pandas is used for data analytics and for reading of dataset which is in .csv format and Data Preprocessing, Pandas is also used for data manipulation, it operations for manipulating numerical data.
#
# **Matplotlib:** For Charts or Plots
#
# **Seaborn:** for Charts or Plots built on top of Matplotlib, it is a data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# **Sklearn:** Scikit-learn library provides many unsupervised and supervised learning algorithms.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2: Load the Dataset

# %%
#load diabetes Dataset
df = pd.read_csv('C:\\Users\\SHIVAM\\Downloads\\diabetes.csv')

# %% [markdown]
# ### Step 3: Data Analysis
#
# Exploratory Data Analysis (EDA), also known as Data Exploration, is a step in the Data Analysis Process, where a number of techniques are used to better understand the dataset being used.
#
#
# In this step, we will perform the below operations:
#
# **3.1) Understanding Your Variables**
#
#        3.1.1) Head of the Dataset
#
#        3.1.2) The shape of the Dataset
#
#        3.1.3) List types of all columns
#
#        3.1.4) Info of the dataset
#
#        3.1.5) Summary of the dataset
#
# **3.2) Data Cleaning**
#
#        3.2.1) Check the DUPLICATES
#
#        3.2.2) Check the NULL values
#
#        3.1.1) Head of the Dataset

# %% [markdown]
# **3.1.1 Head of the Dataset**
#
# The head () function will tell you the top records in the data set. By default, python shows you only the top 5 records.
#
# This head(n) function returns the first n rows for the object based on position. It is useful for quickly testing if your object has the right type of data in it. By default it will show 5 rows.

# %%
#Display first five records of the dataset
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Display last five records of the dataset 
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#Display randomly records of the dataset
df.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 484            0      145              0              0        0  44.2
# 538            0      127             80             37      210  36.3
# 586            8      143             66              0        0  34.9
# 231            6      134             80             37      370  46.2
# 452            0       91             68             32      210  39.9
# 541            3      128             72             25      190  32.4
# 225            1       87             78             27       32  34.6
# 153            1      153             82             42      485  40.6
# 251            2      129             84              0        0  28.0
# 42             7      106             92             18        0  22.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 484                     0.630   31        1
# 538                     0.804   23        0
# 586                     0.129   41        1
# ...

# %% [markdown]
# **3.1.2) The shape of the dataset**
#
# This shape () function gives us the number of rows and columns of the dataset

# %%
#Number of rows and columns
df.shape
# Out:
# (768, 9)

# %% [markdown]
# **3.1.3) List types of all columns**
#
#
# Using df.dtypes, we get the list of types of all the columns in our dataset.

# %%
#List the types of all columns
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# **3.1.4) Info of the dataset**
#
# info() is used to check the Information about the data and the datatypes of each respective attribute.

# %%
#finding out if the dataset contains any null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# **3.1.5) Summary of the dataset**
#
# The described method will help to see how data has been spread for numerical values. We can clearly see the minimum value, mean values different percentile values, and maximum values.

# %%
#Statistical Summary
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# **Observation**
#
# The described method wiil help to see how data has spread for numerical values. We cann clearly see the minimum value, mean value,different percentile values and max min values

# %% [markdown]
# **3.2 Data Cleaning**

# %% [markdown]
# **3.2.1) Drop the Duplicates**
#
# Check is there any duplicate rows are exist or not, if exist then we shold remove from the dataframe.

# %%
#Check the shape before drop the duplicates
df.shape
# Out:
# (768, 9)

# %%
# Drop duplicates
df=df.drop_duplicates()

# %%
# check the shape after drop of the duplicates
df.shape
# Out:
# (768, 9)

# %% [markdown]
# Before drop and after drop the duplicates he data set has same shape which means no duplicates in the dataset.

# %% [markdown]
# **3.2.2) Check the NULL Values**
#
# Using isnull.sum() function we can see the null values present in the every column in the dataset.

# %%
# count of null values
# check the missing values of any column
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# #### Check the number of Zero values in dataset

# %%
print("No. of zero values in Glucose " , df[df['Glucose']==0].shape[0])
# Out:
# No. of zero values in Glucose  5

# %%
print("No. of zero values in BloodPressure " , df[df['BloodPressure']==0].shape[0])
# Out:
# No. of zero values in BloodPressure  35

# %%
print("No. of zero values in SkinThickness " , df[df['SkinThickness']==0].shape[0])
# Out:
# No. of zero values in SkinThickness  227

# %%
print("No. of zero values in Insulin " , df[df['Insulin']==0].shape[0])
# Out:
# No. of zero values in Insulin  374

# %%
print("No. of zero values in BMI " , df[df['BMI']==0].shape[0])
# Out:
# No. of zero values in BMI  11

# %%
print("No. of zero values in Age " , df[df['Age']==0].shape[0])
# Out:
# No. of zero values in Age  0

# %% [markdown]
# #### Replace number of zero values with mean of that columns

# %%
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean())
print("No. of zero values in Glucose " , df[df['Glucose']==0].shape[0])
# Out:
# No. of zero values in Glucose  0

# %%
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean())
print("No. of zero values in BloodPressure " , df[df['BloodPressure']==0].shape[0])
# Out:
# No. of zero values in BloodPressure  0

# %%
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].mean())
print("No. of zero values in SkinThickness " , df[df['SkinThickness']==0].shape[0])
# Out:
# No. of zero values in SkinThickness  0

# %%
df['Insulin']=df['Insulin'].replace(0,df['Insulin'].median())
print("No. of zero values in Insulin " , df[df['Insulin']==0].shape[0])
# Out:
# No. of zero values in Insulin  0

# %%
df['BMI']=df['Insulin'].replace(0,df['BMI'].mean())
print("No. of zero values in BMI " , df[df['BMI']==0].shape[0])
# Out:
# No. of zero values in BMI  0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.681605      72.254807      26.606479   94.652344
# std       3.369578   30.436016      12.115932       9.631241  105.547598
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.536458   30.500000
# 50%       3.000000  117.000000      72.000000      23.000000   31.250000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    94.652344                  0.471876   33.240885    0.348958
# std    105.547598                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ### 4) Data Visualization

# %% [markdown]
# **4.1) Count plot**

# %%
#outcome count plot
f,ax=plt.subplots(1,2,figsize=(10,5))
df['Outcome'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Outcome')
ax[0].set_ylabel('')
sns.countplot('Outcome' ,data=df,ax=ax[1])
ax[1].set_title('Outcome')
N,P=df['Outcome'].value_counts()
print('Negative (0): ' ,N)
print('Positive (1): ' ,P)
plt.grid()
plt.show()
# Out:
# Negative (0):  500
# Positive (1):  268

# %% [markdown]
# **Outcome**
#
# Out of total 768 people, 268 are diabetic (Positive (1)) and 500 are non-diabetic (negative(0).
#
# In the outcome column, 1 represents diabetes positive and 0 represents diabetes negative.
#
# The countplot tells us that the dataset is Imbalanced, as number of patients who don't have diabetes is more than those who have diabetes.

# %% [markdown]
# **4.2) Histograms**
#
# Histograms are one of the most common graphs used to display numeric data.
#
# distribution of the data - Whether the data is normally distributed or if it's skewed (to the left or right)

# %%
#Histogram of each feature
df.hist(bins=10,figsize=(10,10))
plt.show()

# %% [markdown]
# **4.3) Scatter plot**
#
# A scatterplot is a type of graph which 'plots' the values of two variables along two axes, like age and height. Scatterplots are useful for many reasons: like
# correlation matrices, it allows you to quickly understand a relationship between two variables.

# %%
#Scatter
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize = (20,20));

# %% [markdown]
# ##### 4.5) Analyzing relationships between variables
#
# **Correlation analysis**
#
# Correlation analysis is used to quantify the degree to which two variables are related. Through the correlation analysis, you evaluate correlation coefficient that
# tells you how much one variable changes when the other one does. Correlation analysis provides you with a linear relationship between two variables. When
# we correlate feature variables with the target variable, we get to know that how much dependency is there between particular feature variables and target
# variable.

# %%
# correlation of each features in dataset
corr=df.corr()
top_corr_features = corr.index
plt.figure(figsize=(10,10))
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# **Observations:**
#
# From the correaltion heatmap, we can see that there is a high correlation between Outcome and [Pregnancies, Glucose,BMI Age,Insulin. We can selec
# features to accept input from the user and predict the outcome.

# %% [markdown]
# ### 5) Split the data frame into X and Y

# %%
# separating the data and labels
X = df.drop(columns = 'Outcome', axis=1)
Y = df['Outcome']

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0              6    148.0           72.0      35.000000     30.5   30.5
# 1              1     85.0           66.0      29.000000     30.5   30.5
# 2              8    183.0           64.0      20.536458     30.5   30.5
# 3              1     89.0           66.0      23.000000     94.0   94.0
# 4              0    137.0           40.0      35.000000    168.0  168.0
# ..           ...      ...            ...            ...      ...    ...
# 763           10    101.0           76.0      48.000000    180.0  180.0
# 764            2    122.0           70.0      27.000000     30.5   30.5
# 765            5    121.0           72.0      23.000000    112.0  112.0
# 766            1    126.0           60.0      20.536458     30.5   30.5
# 767            1     93.0           70.0      31.000000     30.5   30.5
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# ...

# %%
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# ### 6) Applying Feature Scaling

# %%
#Apply Standard Scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
standardized_data = scaler.transform(X)
print(standardized_data)
# Out:
# [[ 0.63994726  0.86527574 -0.0210444  ... -0.60820096  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.20598931 -0.51658286 ... -0.60820096 -0.36506078
#   -0.19067191]
#  [ 1.23388019  2.01597855 -0.68176235 ... -0.60820096  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808  -0.02240928 -0.0210444  ...  0.16446572 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.14197684 -1.01212132 ... -0.60820096 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.94297153 -0.18622389 ... -0.60820096 -0.47378505
#   -0.87137393]]

# %%
X = standardized_data

# %%
X
# Out:
# array([[ 0.63994726,  0.86527574, -0.0210444 , ..., -0.60820096,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.20598931, -0.51658286, ..., -0.60820096,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  2.01597855, -0.68176235, ..., -0.60820096,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 , -0.02240928, -0.0210444 , ...,  0.16446572,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.14197684, -1.01212132, ..., -0.60820096,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.94297153, -0.18622389, ..., -0.60820096,
#         -0.47378505, -0.87137393]])

# %% [markdown]
# ### 7) Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape , Y_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8) (154,)

# %% [markdown]
# ### K-Fold Cross-Validation
#
# The K-fold cross-validation method splits the input dataset into K equal-sized groups of samples. These samples are called folds. The prediction function employs k-1 folds for each learning set, while the remainder of the folds are utilised for the test set. This strategy is often used in CVs since it is simple to grasp and produces less biassed results than other methods.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold

# %%
models = []
models.append(('NB', GaussianNB()))
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('DTC', DecisionTreeClassifier()))
models.append(('RF', RandomForestClassifier()))
models.append(('SVM', SVC()))

# evaluate each model in turn
results = []
names = []

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score

for name, model in models:
    
        kfold = KFold(n_splits = 10)
        cv_results = cross_val_score(model, X, Y, cv = 10, scoring= "accuracy")
        results.append(cv_results)
        names.append(name)
        msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
        print(msg)
# Out:
# NB: 0.727854 (0.031057)
# LR: 0.763141 (0.047747)
# KNN: 0.735748 (0.041522)
# DTC: 0.669327 (0.049085)
# RF: 0.751333 (0.032338)
# SVM: 0.746172 (0.041962)

# %% [markdown]
# ### 8) Build the Classification Algorithm
#   #### Logistic Regression

# %%
#logistic Regression
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='liblinear', multi_class='ovr')
lr.fit(X_train,Y_train)
# Out:
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %% [markdown]
# ### 9) Making Prediction

# %%
lr_predict = lr.predict(X_test)

# %%
lr_predict.shape
# Out:
# (154,)

# %% [markdown]
# ### 10) Model Evaluation

# %% [markdown]
# **10.1) Train Score and Test Score**

# %%
# accuracy score on the training data
from sklearn.metrics import accuracy_score
X_train_prediction = lr.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7768729641693811

# %%
# accuracy score on the test data
test_data_accuracy = accuracy_score(lr_predict, Y_test)
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.7272727272727273

# %% [markdown]
# **10.2) Confusion Matrix**
#
#
# Confusion metrics is a table which is used to describe the performance of a classification problem.
#
# It visualizes the accuracy of a classifier by comparing predicted values with actual values.
#
# The terms used in confusion metrics are True positive (TP), true negative (TN), false positive (FP) and false negative (FN).
#
# **True Positive:** The predicted result is positive, while it is labeled as positive.
#
# **False Positive:** The predicted result is positive, while it is labeled as negative. It calls Type I Error as well.
#
# **False Negative:** The predicted result is negative, while it is labeled as positive. It calls Type II Error as well.
#
# **True Negative:** The predicted result is negative, while it is labeled as negative.

# %% [markdown]
# **Confusion Matrix of Logistic Regression**

# %%
#Confusion Matrix of Logistic Regression
from sklearn.metrics import classification_report, confusion_matrix
cm = confusion_matrix(Y_test, lr_predict)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[87 13]
#  [29 25]]

# %%
# Heatmap of Confusion Matrix
class_names=[0,1]
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
sns.heatmap(confusion_matrix(Y_test,lr_predict),annot=True,fmt="d")
ax.xaxis.set_label_position("top")
plt.tight_layout()	
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
TN = cm[0,0]
FP = cm[0,1]
FN = cm[1,0]
TP = cm[1,1]

# %%
TN , FP , FN , TP
# Out:
# (87, 13, 29, 25)

# %%
pd.crosstab(Y_test, lr_predict , margins=False)
# Out:
# col_0     0   1
# Outcome
# 0        87  13
# 1        29  25

# %%
pd.crosstab(Y_test, lr_predict , margins=True)
# Out:
# col_0      0   1  All
# Outcome
# 0         87  13  100
# 1         29  25   54
# All      116  38  154

# %%
pd.crosstab(Y_test, lr_predict, rownames=['Actual values'], colnames=['Predicted values'], margins=True)
# Out:
# Predicted values    0   1  All
# Actual values
# 0                  87  13  100
# 1                  29  25   54
# All               116  38  154

# %% [markdown]
# **Classification Report**

# %%
print("Classification Report of Logistic Regression: \n", classification_report(Y_test, lr_predict))
print("Accuracy Rate: ", accuracy_score(lr_predict,Y_test))
# Out:
# Classification Report of Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.75      0.87      0.81       100
#            1       0.66      0.46      0.54        54
#
#     accuracy                           0.73       154
#    macro avg       0.70      0.67      0.67       154
# weighted avg       0.72      0.73      0.71       154
#
# Accuracy Rate:  0.7272727272727273

# %% [markdown]
# **Precision**

# %%
from sklearn.metrics import precision_score
print("Precision Score is: ", precision_score(Y_test, lr_predict)*100)
# Out:
# Precision Score is:  65.78947368421053

# %% [markdown]
# **Recall**

# %%
from sklearn.metrics import recall_score
print("Recall or Sensitivity Score:", recall_score(Y_test, lr_predict)*100)
# Out:
# Recall or Sensitivity Score: 46.2962962962963

# %% [markdown]
# **f1 Scpre**

# %%
from sklearn.metrics import f1_score
print("f1 score is:", f1_score(Y_test, lr_predict)*100)
# Out:
# f1 score is: 54.347826086956516

# %% [markdown]
# ### ROC Curve and ROC AUC
#
# ROC curve is one the important evaluating metrics that should be used to check the performance of an classification model. It is also called relative operating characteristic curve, because it is a comparison of two main characteristics (TPR and FPR). It is plotted between sensitivity(aka recall aka True Positive Rate) and False Positive Rate(FPR=1-specificity).
#
# ROC (Receiver Operating Characteristic) Curve tells us about how good the model can distinguish between two things (e.g If a patient has a disease.or no).
#
# Area Under Curve (AUC) helps us to choose the best model amongst the models for which we have plotted the ROC curves

# %%
#Area under curve
from sklearn.metrics import roc_auc_score, roc_curve
auc = roc_auc_score(Y_test, lr_predict)
print('ROC AUC Score of Logistic Regression is', auc)
# Out:
# ROC AUC Score of Logistic Regression is 0.6664814814814815

# %%
fpr, tpr, thresholds = roc_curve(Y_test, lr_predict)
plt.plot(fpr, tpr, color="orange", label="ROc")
plt.plot([0, 1], [0, 1], color="darkblue", linestyle='--', label='ROC Curve (Area=%0.2f)' % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve of Logistic Regression')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Sample Example of Input Data

# %%
input_data = (5,166,72,19,175,25.8,0.587,51)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardize the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = lr.predict(std_data)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [[ 0.3429808   1.45706576 -0.0210444  -0.79028616  0.76174179 -0.65275965
#    0.34768723  1.51108316]]
# [1]
# The person is diabetic

# %% [markdown]
# ## END
